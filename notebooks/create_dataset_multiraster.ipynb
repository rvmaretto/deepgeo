# %% [markdown]
# # Create datasets from the geotiff images

# %%
import sys
import os
from importlib import reload

sys.path.insert(0, '../src')
import deepleeo.utils.geofunctions as gf

reload(gf)
# Out:
# <module 'deepleeo.utils.geofunctions' from '../src/deepleeo/utils/geofunctions.py'>

# %%
DATA_DIR = os.path.join(os.path.abspath(os.path.dirname("__file__")), '../', 'data_real')
#raster_file = os.path.join(DATA_DIR, "Landsat8_225-64_17-07-2016-R6G5B4.tif")
raster_file = [os.path.join(DATA_DIR, "Landsat8_225064_17072016_R6G5B4.tif"),
               os.path.join(DATA_DIR, "Landsat8_225-64_17-07-2016-R6G5B4_radiance.tif")]
print(raster_file)
# Out:
# ['/home/raian/doutorado/DeepLeEO/notebooks/../data_real/Landsat8_225064_17072016_R6G5B4.tif', '/home/raian/doutorado/DeepLeEO/notebooks/../data_real/Landsat8_225-64_17-07-2016-R6G5B4_radiance.tif']

# %%
img_structure = gf.generate_multi_raster_structure(raster_file, no_data=-9999)

# %%
print(img_structure)
# Out:
# {'band_names': ['band 6 surface reflectance', 'band 5 surface reflectance', 'band 4 surface reflectance'], 'raster_arrays': [masked_array(
#   data=[[[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         ...,
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]]],
#   mask=[[[ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True],
#          ...,
#          [ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True]],
#
#         [[ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True],
#          ...,
#          [ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True]],
#
#         [[ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True],
#          ...,
#          [ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True]],
#
#         ...,
#
#         [[ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True],
#          ...,
#          [ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True]],
#
#         [[ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True],
#          ...,
#          [ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True]],
#
#         [[ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True],
#          ...,
#          [ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True]]],
#   fill_value=999999,
#   dtype=int16), masked_array(
#   data=[[[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         ...,
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]]],
#   mask=[[[ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True],
#          ...,
#          [ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True]],
#
#         [[ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True],
#          ...,
#          [ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True]],
#
#         [[ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True],
#          ...,
#          [ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True]],
#
#         ...,
#
#         [[ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True],
#          ...,
#          [ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True]],
#
#         [[ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True],
#          ...,
#          [ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True]],
#
#         [[ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True],
#          ...,
#          [ True,  True,  True],
#          [ True,  True,  True],
#          [ True,  True,  True]]],
#   fill_value=999999,
#   dtype=uint16)], 'file_paths': ['/home/raian/doutorado/DeepLeEO/notebooks/../data_real/Landsat8_225064_17072016_R6G5B4.tif', '/home/raian/doutorado/DeepLeEO/notebooks/../data_real/Landsat8_225-64_17-07-2016-R6G5B4_radiance.tif']}
