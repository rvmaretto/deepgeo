# %% [markdown]
# # Generate samples for the Deforestation Paper separately

# %%
import sys
import os
import numpy as np
from importlib import reload

sys.path.insert(0, '../../src')
import deepleeo.dataset.rasterizer as rstzr
import deepleeo.dataset.preprocessor as prep
import deepleeo.dataset.chipsGenerator as cg
import deepleeo.utils.geofunctions as gf
import deepleeo.utils.visualization as vis

reload(rstzr)
reload(prep)
reload(cg)
reload(gf)
reload(vis)

# %matplotlib inline
# Out:
# /home/raian/anaconda3/envs/tensorflow/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Input Files
DATA_DIR = "/home/raian/doutorado/Dados/generated"
shape_file = os.path.join(DATA_DIR, 'Prodes_mosaic.shp')
raster_file = os.path.join(DATA_DIR, "mosaic_2016.tif")

#TODO: Generate Samples for 2015 and simply append the arrays to generate the 2015-2016 dataset.

classes_of_interest = ["d2016"]
non_class = "not_deforestation"
class_column = "class_name"

# Output Files
output_path = DATA_DIR
# fs.mkdir(output_path)
out_labels = os.path.join(output_path, "labels_2016.tif")
output_shp = os.path.join(output_path, "samples_2016.shp")
output_npz = os.path.join(output_path, "dataset_286x286_2016.npz")

number_of_samples = 5000
chip_size = 286

# %% [markdown]
# ## Rasterize the input shape file

# %%
rasterizer = rstzr.Rasterizer(shape_file,
                             raster_file,
                             class_column,
                             classes_interest=classes_of_interest,
                             non_class_name=non_class)

rasterizer.collect_class_names()
rasterizer.rasterize_layer()
class_names = rasterizer.get_class_names()
rasterized_layer = rasterizer.get_labeled_raster()

# %%
rasterizer.save_labeled_raster_to_gtiff(out_labels)

# %%
vis.plot_labels(rasterized_layer, class_names, colors=["green", "red"], figsize=(12,12))

# print("UNIQUE: ", np.unique(labels))

# %%
preproc = prep.Preprocessor(raster_file, no_data=-9999)
preproc.set_nodata_value(-10)
original_raster = preproc.get_raster_stacked_raster()
print("SHAPE: ", original_raster.shape)
print("DTYPE: ", original_raster.dtype)

vis.plot_image_histogram(original_raster, title="Original Raster")
vis.plot_rgb_img(original_raster, bands=[3,2,1], contrast=True)
# Out:
# SHAPE:  (11534, 13587, 5)
# DTYPE:  int16
# /home/raian/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/util/dtype.py:118: UserWarning: Possible sign loss when converting negative image of type int16 to positive image of type uint8.
#   .format(dtypeobj_in, dtypeobj_out))
# /home/raian/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from int16 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
preproc.standardize_image("median_std")
raster_img = preproc.get_raster_stacked_raster()
print("DTYPE: ", raster_img.dtype)
vis.plot_image_histogram(raster_img, title="Standardized Raster")
# Out:
# DTYPE:  float32

# %%
reload(cg)
chpGen = cg.ChipsGenerator(raster_img, rasterized_layer, class_names, raster_file)
chpGen.compute_sample_indexes(number_of_samples, class_of_interest='d2016')
chpGen.extract_windows(chip_size)
samples_2016 = chpGen.getSamples()
print("Generated ", len(samples_2016["images"]), " image samples.")
print("Generated ", len(samples_2016["labels"]), " label samples.")
chpGen.save_samples_SHP(output_shp)
chpGen.save_samples_NPZ(output_npz)
# Out:
# Generated  5000  image samples.
# Generated  5000  label samples.

# %%
reload(vis)
vis.plot_vector_file(output_shp)

# %% [markdown]
# # Generate Samples for 2015

# %%
# Input Files
shape_file_2015 = os.path.join(DATA_DIR, 'Prodes_mosaic.shp')
raster_file_2015 = os.path.join(DATA_DIR, "mosaic_2015.tif")

#TODO: Generate Samples for 2015 and simply append the arrays to generate the 2015-2016 dataset.

classes_of_interest = ["d2015"]
non_class = "not_deforestation"
class_column = "class_name"

# Output Files
output_path = DATA_DIR
# fs.mkdir(output_path)
out_labels = os.path.join(output_path, "labels_2015.tif")
output_shp = os.path.join(output_path, "samples_2015.shp")
output_npz = os.path.join(output_path, "dataset_286x286_2015-2016-sep.npz")

number_of_samples = 5000
chip_size = 286

# %%
rasterizer = rstzr.Rasterizer(shape_file_2015,
                              raster_file_2015,
                              class_column,
                              classes_interest=classes_of_interest,
                              non_class_name=non_class)

rasterizer.collect_class_names()
rasterizer.rasterize_layer()
class_names = rasterizer.get_class_names()
rasterized_layer = rasterizer.get_labeled_raster()

# %%
rasterizer.save_labeled_raster_to_gtiff(out_labels)

# %%
vis.plot_labels(rasterized_layer, class_names, colors=["green", "red"])

# print("UNIQUE: ", np.unique(labels))

# %%
preproc = prep.Preprocessor(raster_file_2015, no_data=-9999)
preproc.set_nodata_value(-10)
original_raster = preproc.get_raster_stacked_raster()
print("SHAPE: ", original_raster.shape)
# print("UNIQUE: ", np.unique(original_raster))

vis.plot_image_histogram(original_raster, title="Original Raster")
vis.plot_rgb_img(original_raster, bands=[3,2,1], contrast=True)
# Out:
# SHAPE:  (11534, 13587, 5)
# /home/raian/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/util/dtype.py:118: UserWarning: Possible sign loss when converting negative image of type int16 to positive image of type uint8.
#   .format(dtypeobj_in, dtypeobj_out))
# /home/raian/anaconda3/envs/tensorflow/lib/python3.5/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from int16 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
preproc.standardize_image("median_std")
raster_img = preproc.get_raster_stacked_raster()
# print(np.unique(raster_img))
vis.plot_image_histogram(raster_img, title="Standardized Raster")

# %%
reload(cg)
chpGen = cg.ChipsGenerator(raster_img, rasterized_layer, class_names, raster_file)
chpGen.compute_sample_indexes(number_of_samples, class_of_interest='d2015')
chpGen.extract_windows(chip_size)
samples_2015 = chpGen.getSamples()
print("Generated ", len(samples_2015["images"]), " image samples.")
print("Generated ", len(samples_2015["labels"]), " label samples.")
print("Classes: ", samples_2015["classes"])
chpGen.save_samples_SHP(output_shp)
# chpGen.save_samples_NPZ(output_npz)
# Out:
# Generated  5000  image samples.
# Generated  5000  label samples.
# Classes:  ['not_deforestation', 'd2015']

# %%
reload(vis)
vis.plot_vector_file(output_shp)

# %%
samples = {"images": samples_2015["images"] + samples_2016["images"],
           "labels": samples_2015["labels"] + samples_2016["labels"] ,
           "classes": ["not_deforestation", "deforestation"]
}

# %%
np.savez(output_npz,
         images = samples["images"],
         labels= samples["labels"],
         classes=np.array(samples["classes"]))

# %% [markdown]
# # Rasterize 2013 and 2014 data

# %%
# Input Files
shape_file_2014 = os.path.join(DATA_DIR, 'Prodes_mosaic.shp')
raster_file_2014 = os.path.join(DATA_DIR, "mosaic_2014.tif")

#TODO: Generate Samples for 2015 and simply append the arrays to generate the 2015-2016 dataset.

classes_of_interest = ["d2014"]
non_class = "not_deforestation"
class_column = "class_name"

# Output Files
output_path = DATA_DIR
# fs.mkdir(output_path)
out_labels = os.path.join(output_path, "labels_2014.tif")
output_shp = os.path.join(output_path, "samples_2014.shp")
# output_npz = os.path.join(output_path, "dataset_286x286_2015-2016-sep.npz")

number_of_samples = 5000
chip_size = 286

# %%
rasterizer = rstzr.Rasterizer(shape_file_2014,
                              raster_file_2014,
                              class_column,
                              classes_interest=classes_of_interest,
                              non_class_name=non_class)

rasterizer.collect_class_names()
rasterizer.rasterize_layer()
class_names = rasterizer.get_class_names()
rasterized_layer = rasterizer.get_labeled_raster()

# %%
rasterizer.save_labeled_raster_to_gtiff(out_labels)

# %%
vis.plot_labels(rasterized_layer, class_names, colors=["green", "red"])

# print("UNIQUE: ", np.unique(labels))

# %%
# Input Files
shape_file_2013 = os.path.join(DATA_DIR, 'Prodes_mosaic.shp')
raster_file_2013 = os.path.join(DATA_DIR, "mosaic_2013.tif")

#TODO: Generate Samples for 2015 and simply append the arrays to generate the 2015-2016 dataset.

classes_of_interest = ["d2013"]
non_class = "not_deforestation"
class_column = "class_name"

# Output Files
output_path = DATA_DIR
# fs.mkdir(output_path)
out_labels = os.path.join(output_path, "labels_2013.tif")
output_shp = os.path.join(output_path, "samples_2013.shp")
# output_npz = os.path.join(output_path, "dataset_286x286_2015-2016-sep.npz")

number_of_samples = 5000
chip_size = 286

# %%
rasterizer = rstzr.Rasterizer(shape_file_2014,
                              raster_file_2014,
                              class_column,
                              classes_interest=classes_of_interest,
                              non_class_name=non_class)

rasterizer.collect_class_names()
rasterizer.rasterize_layer()
class_names = rasterizer.get_class_names()
rasterized_layer = rasterizer.get_labeled_raster()

# %%
rasterizer.save_labeled_raster_to_gtiff(out_labels)

# %%
vis.plot_labels(rasterized_layer, class_names, colors=["green", "red"])

# print("UNIQUE: ", np.unique(labels))
